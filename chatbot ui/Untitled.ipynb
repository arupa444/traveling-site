# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import torch
import spacy
import json
from sklearn.naive_bayes import MultinomialNB


nlp = spacy.load('en_core_web_sm')

# %%
with open('train_data.json') as f:
    d = json.load(f)

df1 =pd.json_normalize(d, record_path = ['data'])
df2 = pd.json_normalize(d, record_path = ['data','paragraphs'])
df3 = pd.json_normalize(d, record_path = ['data','paragraphs','qas'])
df4 = pd.json_normalize(d, record_path = ['data','paragraphs','qas','answers'])

# %%
df1.head()
# Out:
#                                             title  \
# 0                                         Beyoncé
# 1                                 Frédéric_Chopin
# 2  Sino-Tibetan_relations_during_the_Ming_dynasty
# 3                                            IPod
# 4          The_Legend_of_Zelda:_Twilight_Princess
#
#                                           paragraphs
# 0  [{'qas': [{'question': 'When did Beyonce start...
# 1  [{'qas': [{'question': "What was Frédéric's na...
# 2  [{'qas': [{'question': 'Who were Wang Jiawei a...
# 3  [{'qas': [{'question': 'Which company produces...
# 4  [{'qas': [{'question': 'What category of game ...

# %%
df2.head()
# Out:
#                                                  qas  \
# 0  [{'question': 'When did Beyonce start becoming...
# 1  [{'question': 'After her second solo album, wh...
# 2  [{'question': 'In her music, what are some rec...
# 3  [{'question': 'Beyonce's younger sibling also ...
# 4  [{'question': 'What town did Beyonce go to sch...
#
#                                              context
# 0  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1  Following the disbandment of Destiny's Child i...
# 2  A self-described "modern-day feminist", Beyonc...
# 3  Beyoncé Giselle Knowles was born in Houston, T...
# 4  Beyoncé attended St. Mary's Elementary School ...

# %%
df3.head()
# Out:
#                                             question  \
# 0           When did Beyonce start becoming popular?
# 1  What areas did Beyonce compete in when she was...
# 2  When did Beyonce leave Destiny's Child and bec...
# 3      In what city and state did Beyonce  grow up?
# 4         In which decade did Beyonce become famous?
#
#                          id  \
# 0  56be85543aeaaa14008c9063
# 1  56be85543aeaaa14008c9065
# 2  56be85543aeaaa14008c9066
# 3  56bf6b0f3aeaaa14008c9601
# 4  56bf6b0f3aeaaa14008c9602
#
#                                              answers  is_impossible  \
# 0  [{'text': 'in the late 1990s', 'answer_start':...          False
# 1  [{'text': 'singing and dancing', 'answer_start...          False
# 2            [{'text': '2003', 'answer_start': 526}]          False
# 3  [{'text': 'Houston, Texas', 'answer_start': 166}]          False
# 4      [{'text': 'late 1990s', 'answer_start': 276}]          False
#
#   plausible_answers
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
df3
# Out:
#                                                  question  \
# 0                When did Beyonce start becoming popular?
# 1       What areas did Beyonce compete in when she was...
# 2       When did Beyonce leave Destiny's Child and bec...
# 3           In what city and state did Beyonce  grow up?
# 4              In which decade did Beyonce become famous?
# ...                                                   ...
# 130314  Physics has broadly agreed on the definition o...
# 130315               Who coined the term partonic matter?
# 130316              What is another name for anti-matter?
# 130317  Matter usually does not need to be used in con...
# 130318  What field of study has a variety of unusual c...
#
#                               id  \
# 0       56be85543aeaaa14008c9063
# 1       56be85543aeaaa14008c9065
# 2       56be85543aeaaa14008c9066
# 3       56bf6b0f3aeaaa14008c9601
# 4       56bf6b0f3aeaaa14008c9602
# ...                          ...
# 130314  5a7e070b70df9f001a875439
# 130315  5a7e070b70df9f001a87543a
# 130316  5a7e070b70df9f001a87543b
# 130317  5a7e070b70df9f001a87543c
# 130318  5a7e070b70df9f001a87543d
#
#                                                   answers  is_impossible  \
# 0       [{'text': 'in the late 1990s', 'answer_start':...          False
# 1       [{'text': 'singing and dancing', 'answer_start...          False
# 2                 [{'text': '2003', 'answer_start': 526}]          False
# 3       [{'text': 'Houston, Texas', 'answer_start': 166}]          False
# 4           [{'text': 'late 1990s', 'answer_start': 276}]          False
# ...                                                   ...            ...
# 130314                                                 []           True
# 130315                                                 []           True
# 130316                                                 []           True
# 130317                                                 []           True
# 130318                                                 []           True
#
#                                         plausible_answers
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 130314          [{'text': 'matter', 'answer_start': 485}]
# 130315          [{'text': 'Alfvén', 'answer_start': 327}]
# 130316  [{'text': 'Gk. common matter', 'answer_start':...
# 130317  [{'text': 'a specifying modifier', 'answer_sta...
# 130318          [{'text': 'physics', 'answer_start': 37}]
#
# [130319 rows x 5 columns]

# %%
df4.head()
# Out:
#                   text  answer_start
# 0    in the late 1990s           269
# 1  singing and dancing           207
# 2                 2003           526
# 3       Houston, Texas           166
# 4           late 1990s           276

# %%
df = pd.concat([df1,df2,df3,df4], axis = 1)

# %%
df
# Out:
#                                                  title  \
# 0                                              Beyoncé
# 1                                      Frédéric_Chopin
# 2       Sino-Tibetan_relations_during_the_Ming_dynasty
# 3                                                 IPod
# 4               The_Legend_of_Zelda:_Twilight_Princess
# ...                                                ...
# 130314                                             NaN
# 130315                                             NaN
# 130316                                             NaN
# 130317                                             NaN
# 130318                                             NaN
#
#                                                paragraphs  \
# 0       [{'qas': [{'question': 'When did Beyonce start...
# 1       [{'qas': [{'question': "What was Frédéric's na...
# 2       [{'qas': [{'question': 'Who were Wang Jiawei a...
# 3       [{'qas': [{'question': 'Which company produces...
# 4       [{'qas': [{'question': 'What category of game ...
# ...                                                   ...
# 130314                                                NaN
# 130315                                                NaN
# 130316                                                NaN
# 130317                                                NaN
# 130318                                                NaN
#
#                                                       qas  \
# 0       [{'question': 'When did Beyonce start becoming...
# 1       [{'question': 'After her second solo album, wh...
# 2       [{'question': 'In her music, what are some rec...
# 3       [{'question': 'Beyonce's younger sibling also ...
# 4       [{'question': 'What town did Beyonce go to sch...
# ...                                                   ...
# 130314                                                NaN
# 130315                                                NaN
# 130316                                                NaN
# 130317                                                NaN
# 130318                                                NaN
#
#                                                   context  \
# 0       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1       Following the disbandment of Destiny's Child i...
# 2       A self-described "modern-day feminist", Beyonc...
# 3       Beyoncé Giselle Knowles was born in Houston, T...
# 4       Beyoncé attended St. Mary's Elementary School ...
# ...                                                   ...
# 130314                                                NaN
# 130315                                                NaN
# 130316                                                NaN
# 130317                                                NaN
# 130318                                                NaN
#
#                                                  question  \
# 0                When did Beyonce start becoming popular?
# 1       What areas did Beyonce compete in when she was...
# 2       When did Beyonce leave Destiny's Child and bec...
# 3           In what city and state did Beyonce  grow up?
# 4              In which decade did Beyonce become famous?
# ...                                                   ...
# 130314  Physics has broadly agreed on the definition o...
# 130315               Who coined the term partonic matter?
# 130316              What is another name for anti-matter?
# 130317  Matter usually does not need to be used in con...
# 130318  What field of study has a variety of unusual c...
#
#                               id  \
# 0       56be85543aeaaa14008c9063
# 1       56be85543aeaaa14008c9065
# 2       56be85543aeaaa14008c9066
# 3       56bf6b0f3aeaaa14008c9601
# 4       56bf6b0f3aeaaa14008c9602
# ...                          ...
# 130314  5a7e070b70df9f001a875439
# 130315  5a7e070b70df9f001a87543a
# 130316  5a7e070b70df9f001a87543b
# 130317  5a7e070b70df9f001a87543c
# 130318  5a7e070b70df9f001a87543d
#
#                                                   answers  is_impossible  \
# 0       [{'text': 'in the late 1990s', 'answer_start':...          False
# 1       [{'text': 'singing and dancing', 'answer_start...          False
# 2                 [{'text': '2003', 'answer_start': 526}]          False
# 3       [{'text': 'Houston, Texas', 'answer_start': 166}]          False
# 4           [{'text': 'late 1990s', 'answer_start': 276}]          False
# ...                                                   ...            ...
# 130314                                                 []           True
# 130315                                                 []           True
# 130316                                                 []           True
# 130317                                                 []           True
# 130318                                                 []           True
#
#                                         plausible_answers  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 130314          [{'text': 'matter', 'answer_start': 485}]
# 130315          [{'text': 'Alfvén', 'answer_start': 327}]
# 130316  [{'text': 'Gk. common matter', 'answer_start':...
# 130317  [{'text': 'a specifying modifier', 'answer_sta...
# 130318          [{'text': 'physics', 'answer_start': 37}]
#
#                        text  answer_start
# 0         in the late 1990s         269.0
# 1       singing and dancing         207.0
# 2                      2003         526.0
# 3            Houston, Texas         166.0
# 4                late 1990s         276.0
# ...                     ...           ...
# 130314                  NaN           NaN
# 130315                  NaN           NaN
# 130316                  NaN           NaN
# 130317                  NaN           NaN
# 130318                  NaN           NaN
#
# [130319 rows x 11 columns]

# %%
df_true = df[df['is_impossible'] == True]
df_true.drop(columns = ['text','answer_start','id','is_impossible','title'],inplace = True)
def replace_nan_with_empty_list(x):
    if pd.isna(x):
        return ''
    return x

df_true['context'] = df_true['context'].apply(replace_nan_with_empty_list)
df_true['context_new'] = df_true['context'] + df_true['question']
# Out:
# C:\Users\Bharadwaj\AppData\Local\Temp\ipykernel_17744\2948866478.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_true.drop(columns = ['text','answer_start','id','is_impossible','title'],inplace = True)
# C:\Users\Bharadwaj\AppData\Local\Temp\ipykernel_17744\2948866478.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_true['context'] = df_true['context'].apply(replace_nan_with_empty_list)
# C:\Users\Bharadwaj\AppData\Local\Temp\ipykernel_17744\2948866478.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_true['context_new'] = df_true['context'] + df_true['question']

# %%
df_true
# Out:
#        paragraphs                                                qas  \
# 2075          NaN  [{'question': 'More people belong to what reli...
# 2076          NaN  [{'question': 'Which religion will have the mo...
# 2077          NaN  [{'question': 'What denomination of Christiani...
# 2078          NaN  [{'plausible_answers': [{'text': 'sciences, ar...
# 2079          NaN  [{'plausible_answers': [{'text': 'made a myria...
# ...           ...                                                ...
# 130314        NaN                                                NaN
# 130315        NaN                                                NaN
# 130316        NaN                                                NaN
# 130317        NaN                                                NaN
# 130318        NaN                                                NaN
#
#                                                   context  \
# 2075    Christianity remains the dominant religion in ...
# 2076    According to 2012 Pew Research Center survey i...
# 2077    According to Scientific Elite: Nobel Laureates...
# 2078    Christians have made a myriad contributions in...
# 2079    Christians have made a myriad contributions in...
# ...                                                   ...
# 130314
# 130315
# 130316
# 130317
# 130318
#
#                                                  question answers  \
# 2075    What category of game is Legend of Zelda: Aust...      []
# 2076    What consoles can be used to play Australia Tw...      []
# 2077    When was Australia Twilight launched in North ...      []
# 2078    When could GameCube owners purchase Australian...      []
# 2079    What year was the Legend of Zelda: Australian ...      []
# ...                                                   ...     ...
# 130314  Physics has broadly agreed on the definition o...      []
# 130315               Who coined the term partonic matter?      []
# 130316              What is another name for anti-matter?      []
# 130317  Matter usually does not need to be used in con...      []
# 130318  What field of study has a variety of unusual c...      []
#
#                                         plausible_answers  \
# 2075    [{'text': 'action-adventure', 'answer_start': ...
# 2076    [{'text': 'GameCube and Wii', 'answer_start': ...
# 2077     [{'text': 'November 2006', 'answer_start': 569}]
# 2078     [{'text': 'November 2006', 'answer_start': 569}]
# 2079              [{'text': '2005', 'answer_start': 364}]
# ...                                                   ...
# 130314          [{'text': 'matter', 'answer_start': 485}]
# 130315          [{'text': 'Alfvén', 'answer_start': 327}]
# 130316  [{'text': 'Gk. common matter', 'answer_start':...
# 130317  [{'text': 'a specifying modifier', 'answer_sta...
# 130318          [{'text': 'physics', 'answer_start': 37}]
#
#                                               context_new
# 2075    Christianity remains the dominant religion in ...
# 2076    According to 2012 Pew Research Center survey i...
# 2077    According to Scientific Elite: Nobel Laureates...
# 2078    Christians have made a myriad contributions in...
# 2079    Christians have made a myriad contributions in...
# ...                                                   ...
# 130314  Physics has broadly agreed on the definition o...
# 130315               Who coined the term partonic matter?
# 130316              What is another name for anti-matter?
# 130317  Matter usually does not need to be used in con...
# 130318  What field of study has a variety of unusual c...
#
# [43498 rows x 7 columns]

# %%
df5 = pd.json_normalize(df['plausible_answers'].explode())

# %%
df_true_res = pd.concat([df_true,df5],axis = 1)

# %%
df_true_res.drop(columns = ['context','question','plausible_answers','answer_start'],inplace = True)

# %%
df_t = df_true_res.dropna()

# %%
df_t
# Out:
# Empty DataFrame
# Columns: [paragraphs, qas, answers, context_new, text]
# Index: []

# %%
df_false = df[df['is_impossible'] == False]

# %%
df_false.drop(columns = ['is_impossible','plausible_answers','id','answer_start'],inplace = True)
def replace_nan_with_empty_list(x):
    if pd.isna(x):
        return ''
    return x

df_false['title'] = df_false['title'].apply(replace_nan_with_empty_list)
df_false['context'] = df_false['context'].apply(replace_nan_with_empty_list)
df_false['context_new'] = df_false['title'] + df_false['question'] + df_false['context']
# Out:
# C:\Users\Bharadwaj\AppData\Local\Temp\ipykernel_17744\2678043030.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_false.drop(columns = ['is_impossible','plausible_answers','id','answer_start'],inplace = True)
# C:\Users\Bharadwaj\AppData\Local\Temp\ipykernel_17744\2678043030.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_false['title'] = df_false['title'].apply(replace_nan_with_empty_list)
# C:\Users\Bharadwaj\AppData\Local\Temp\ipykernel_17744\2678043030.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_false['context'] = df_false['context'].apply(replace_nan_with_empty_list)
# C:\Users\Bharadwaj\AppData\Local\Temp\ipykernel_17744\2678043030.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_false['context_new'] = df_false['title'] + df_false['question'] + df_false['context']

# %%
df_false.drop(columns = ['title','context','question'],inplace = True)
# Out:
# C:\Users\Bharadwaj\AppData\Local\Temp\ipykernel_17744\704110626.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_false.drop(columns = ['title','context','question'],inplace = True)

# %%
df_f = df_false.dropna()

# %%
df_f
# Out:
#                                             paragraphs  \
# 0    [{'qas': [{'question': 'When did Beyonce start...
# 1    [{'qas': [{'question': "What was Frédéric's na...
# 2    [{'qas': [{'question': 'Who were Wang Jiawei a...
# 3    [{'qas': [{'question': 'Which company produces...
# 4    [{'qas': [{'question': 'What category of game ...
# ..                                                 ...
# 437  [{'qas': [{'question': 'Of the huge amount of ...
# 438  [{'qas': [{'question': 'What is the practice o...
# 439  [{'qas': [{'question': 'What country is Kathma...
# 440  [{'qas': [{'plausible_answers': [{'text': 'Myo...
# 441  [{'qas': [{'plausible_answers': [{'text': 'ord...
#
#                                                    qas  \
# 0    [{'question': 'When did Beyonce start becoming...
# 1    [{'question': 'After her second solo album, wh...
# 2    [{'question': 'In her music, what are some rec...
# 3    [{'question': 'Beyonce's younger sibling also ...
# 4    [{'question': 'What town did Beyonce go to sch...
# ..                                                 ...
# 437  [{'question': 'What was the name of the Lenape...
# 438  [{'question': 'In what year did the first Euro...
# 439  [{'question': 'In what year did a Spanish expe...
# 440  [{'question': 'What was the name of the explor...
# 441  [{'question': 'Where was Juan Rodriguez born?'...
#
#                                                answers                  text  \
# 0    [{'text': 'in the late 1990s', 'answer_start':...     in the late 1990s
# 1    [{'text': 'singing and dancing', 'answer_start...   singing and dancing
# 2              [{'text': '2003', 'answer_start': 526}]                  2003
# 3    [{'text': 'Houston, Texas', 'answer_start': 166}]        Houston, Texas
# 4        [{'text': 'late 1990s', 'answer_start': 276}]            late 1990s
# ..                                                 ...                   ...
# 437  [{'text': 'co-producing credits', 'answer_star...  co-producing credits
# 438        [{'text': 'melodies', 'answer_start': 564}]              melodies
# 439           [{'text': 'Women', 'answer_start': 210}]                 Women
# 440    [{'text': 'co-producing', 'answer_start': 376}]          co-producing
# 441  [{'text': 'melodies and ideas', 'answer_start'...    melodies and ideas
#
#                                            context_new
# 0    BeyoncéWhen did Beyonce start becoming popular...
# 1    Frédéric_ChopinWhat areas did Beyonce compete ...
# 2    Sino-Tibetan_relations_during_the_Ming_dynasty...
# 3    IPodIn what city and state did Beyonce  grow u...
# 4    The_Legend_of_Zelda:_Twilight_PrincessIn which...
# ..                                                 ...
# 437  InfectionWhat does she get credits for in her ...
# 438  HuntingWhat part of production does she do?The...
# 439  KathmanduBeyoncé's early recordings empowered ...
# 440  Myocardial_infarctionIn addition to co-writing...
# 441  MatterRather than beats, what two things does ...
#
# [442 rows x 5 columns]

# %%
df.drop(columns = ['paragraphs','qas','answers'],inplace = True)

# %%
df.head()
# Out:
#                                             title  \
# 0                                         Beyoncé
# 1                                 Frédéric_Chopin
# 2  Sino-Tibetan_relations_during_the_Ming_dynasty
# 3                                            IPod
# 4          The_Legend_of_Zelda:_Twilight_Princess
#
#                                              context  \
# 0  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1  Following the disbandment of Destiny's Child i...
# 2  A self-described "modern-day feminist", Beyonc...
# 3  Beyoncé Giselle Knowles was born in Houston, T...
# 4  Beyoncé attended St. Mary's Elementary School ...
#
#                                             question  \
# 0           When did Beyonce start becoming popular?
# 1  What areas did Beyonce compete in when she was...
# 2  When did Beyonce leave Destiny's Child and bec...
# 3      In what city and state did Beyonce  grow up?
# 4         In which decade did Beyonce become famous?
#
#                          id  is_impossible plausible_answers  \
# 0  56be85543aeaaa14008c9063          False               NaN
# 1  56be85543aeaaa14008c9065          False               NaN
# 2  56be85543aeaaa14008c9066          False               NaN
# 3  56bf6b0f3aeaaa14008c9601          False               NaN
# 4  56bf6b0f3aeaaa14008c9602          False               NaN
#
#                   text  answer_start
# 0    in the late 1990s         269.0
# 1  singing and dancing         207.0
# 2                 2003         526.0
# 3       Houston, Texas         166.0
# 4           late 1990s         276.0

# %%
df
# Out:
#                                                  title  \
# 0                                              Beyoncé
# 1                                      Frédéric_Chopin
# 2       Sino-Tibetan_relations_during_the_Ming_dynasty
# 3                                                 IPod
# 4               The_Legend_of_Zelda:_Twilight_Princess
# ...                                                ...
# 130314                                             NaN
# 130315                                             NaN
# 130316                                             NaN
# 130317                                             NaN
# 130318                                             NaN
#
#                                                   context  \
# 0       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1       Following the disbandment of Destiny's Child i...
# 2       A self-described "modern-day feminist", Beyonc...
# 3       Beyoncé Giselle Knowles was born in Houston, T...
# 4       Beyoncé attended St. Mary's Elementary School ...
# ...                                                   ...
# 130314                                                NaN
# 130315                                                NaN
# 130316                                                NaN
# 130317                                                NaN
# 130318                                                NaN
#
#                                                  question  \
# 0                When did Beyonce start becoming popular?
# 1       What areas did Beyonce compete in when she was...
# 2       When did Beyonce leave Destiny's Child and bec...
# 3           In what city and state did Beyonce  grow up?
# 4              In which decade did Beyonce become famous?
# ...                                                   ...
# 130314  Physics has broadly agreed on the definition o...
# 130315               Who coined the term partonic matter?
# 130316              What is another name for anti-matter?
# 130317  Matter usually does not need to be used in con...
# 130318  What field of study has a variety of unusual c...
#
#                               id  is_impossible  \
# 0       56be85543aeaaa14008c9063          False
# 1       56be85543aeaaa14008c9065          False
# 2       56be85543aeaaa14008c9066          False
# 3       56bf6b0f3aeaaa14008c9601          False
# 4       56bf6b0f3aeaaa14008c9602          False
# ...                          ...            ...
# 130314  5a7e070b70df9f001a875439           True
# 130315  5a7e070b70df9f001a87543a           True
# 130316  5a7e070b70df9f001a87543b           True
# 130317  5a7e070b70df9f001a87543c           True
# 130318  5a7e070b70df9f001a87543d           True
#
#                                         plausible_answers  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 130314          [{'text': 'matter', 'answer_start': 485}]
# 130315          [{'text': 'Alfvén', 'answer_start': 327}]
# 130316  [{'text': 'Gk. common matter', 'answer_start':...
# 130317  [{'text': 'a specifying modifier', 'answer_sta...
# 130318          [{'text': 'physics', 'answer_start': 37}]
#
#                        text  answer_start
# 0         in the late 1990s         269.0
# 1       singing and dancing         207.0
# 2                      2003         526.0
# 3            Houston, Texas         166.0
# 4                late 1990s         276.0
# ...                     ...           ...
# 130314                  NaN           NaN
# 130315                  NaN           NaN
# 130316                  NaN           NaN
# 130317                  NaN           NaN
# 130318                  NaN           NaN
#
# [130319 rows x 8 columns]

# %%
df_total = pd.concat([df_t,df_f],axis = 0)

# %%
df_total
# Out:
#                                             paragraphs  \
# 0    [{'qas': [{'question': 'When did Beyonce start...
# 1    [{'qas': [{'question': "What was Frédéric's na...
# 2    [{'qas': [{'question': 'Who were Wang Jiawei a...
# 3    [{'qas': [{'question': 'Which company produces...
# 4    [{'qas': [{'question': 'What category of game ...
# ..                                                 ...
# 437  [{'qas': [{'question': 'Of the huge amount of ...
# 438  [{'qas': [{'question': 'What is the practice o...
# 439  [{'qas': [{'question': 'What country is Kathma...
# 440  [{'qas': [{'plausible_answers': [{'text': 'Myo...
# 441  [{'qas': [{'plausible_answers': [{'text': 'ord...
#
#                                                    qas  \
# 0    [{'question': 'When did Beyonce start becoming...
# 1    [{'question': 'After her second solo album, wh...
# 2    [{'question': 'In her music, what are some rec...
# 3    [{'question': 'Beyonce's younger sibling also ...
# 4    [{'question': 'What town did Beyonce go to sch...
# ..                                                 ...
# 437  [{'question': 'What was the name of the Lenape...
# 438  [{'question': 'In what year did the first Euro...
# 439  [{'question': 'In what year did a Spanish expe...
# 440  [{'question': 'What was the name of the explor...
# 441  [{'question': 'Where was Juan Rodriguez born?'...
#
#                                                answers  \
# 0    [{'text': 'in the late 1990s', 'answer_start':...
# 1    [{'text': 'singing and dancing', 'answer_start...
# 2              [{'text': '2003', 'answer_start': 526}]
# 3    [{'text': 'Houston, Texas', 'answer_start': 166}]
# 4        [{'text': 'late 1990s', 'answer_start': 276}]
# ..                                                 ...
# 437  [{'text': 'co-producing credits', 'answer_star...
# 438        [{'text': 'melodies', 'answer_start': 564}]
# 439           [{'text': 'Women', 'answer_start': 210}]
# 440    [{'text': 'co-producing', 'answer_start': 376}]
# 441  [{'text': 'melodies and ideas', 'answer_start'...
#
#                                            context_new                  text
# 0    BeyoncéWhen did Beyonce start becoming popular...     in the late 1990s
# 1    Frédéric_ChopinWhat areas did Beyonce compete ...   singing and dancing
# 2    Sino-Tibetan_relations_during_the_Ming_dynasty...                  2003
# 3    IPodIn what city and state did Beyonce  grow u...        Houston, Texas
# 4    The_Legend_of_Zelda:_Twilight_PrincessIn which...            late 1990s
# ..                                                 ...                   ...
# 437  InfectionWhat does she get credits for in her ...  co-producing credits
# 438  HuntingWhat part of production does she do?The...              melodies
# 439  KathmanduBeyoncé's early recordings empowered ...                 Women
# 440  Myocardial_infarctionIn addition to co-writing...          co-producing
# 441  MatterRather than beats, what two things does ...    melodies and ideas
#
# [442 rows x 5 columns]

# %%
def preprocess(text):
    doc = nlp(text)
    filtered_tokens = []
    for token in doc:
        if not token.is_punct and not token.is_stop:
            filtered_tokens.append(token.lemma_)
    return ' '.join(filtered_tokens)

# %%
df_total['context_new1'] = df_total['context_new'].apply(preprocess)

# %%
df_total.head()
# Out:
#                                           paragraphs  \
# 0  [{'qas': [{'question': 'When did Beyonce start...
# 1  [{'qas': [{'question': "What was Frédéric's na...
# 2  [{'qas': [{'question': 'Who were Wang Jiawei a...
# 3  [{'qas': [{'question': 'Which company produces...
# 4  [{'qas': [{'question': 'What category of game ...
#
#                                                  qas  \
# 0  [{'question': 'When did Beyonce start becoming...
# 1  [{'question': 'After her second solo album, wh...
# 2  [{'question': 'In her music, what are some rec...
# 3  [{'question': 'Beyonce's younger sibling also ...
# 4  [{'question': 'What town did Beyonce go to sch...
#
#                                              answers  \
# 0  [{'text': 'in the late 1990s', 'answer_start':...
# 1  [{'text': 'singing and dancing', 'answer_start...
# 2            [{'text': '2003', 'answer_start': 526}]
# 3  [{'text': 'Houston, Texas', 'answer_start': 166}]
# 4      [{'text': 'late 1990s', 'answer_start': 276}]
#
#                                          context_new                 text  \
# 0  BeyoncéWhen did Beyonce start becoming popular...    in the late 1990s
# 1  Frédéric_ChopinWhat areas did Beyonce compete ...  singing and dancing
# 2  Sino-Tibetan_relations_during_the_Ming_dynasty...                 2003
# 3  IPodIn what city and state did Beyonce  grow u...       Houston, Texas
# 4  The_Legend_of_Zelda:_Twilight_PrincessIn which...           late 1990s
#
#                                         context_new1
# 0  BeyoncéWhen Beyonce start popular?beyoncé Gise...
# 1  frédéric_chopinwhat area Beyonce compete grow ...
# 2  sino tibetan_relations_during_the_ming_dynasty...
# 3  ipodin city state Beyonce   grow Beyoncé Gisel...
# 4  The_Legend_of_Zelda:_Twilight_PrincessIn decad...

# %%
X_train,X_test,y_train,y_test = train_test_split(
    df_total['context_new1'],
    df_total['text'],
    random_state = 1,
    test_size = 0.2
)

# %%
clf = Pipeline([
    ('vectorizer', TfidfVectorizer(ngram_range=(1, 2))), 
    ('classifier', LogisticRegression())  
])

# %%
clf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('vectorizer', TfidfVectorizer(ngram_range=(1, 2))),
#                 ('classifier', LogisticRegression())])

# %%
y_pred = clf.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#                                     precision    recall  f1-score   support
#
#                 '03 Bonnie & Clyde       0.00      0.00      0.00         1
#                                132       0.00      0.00      0.00         1
#                      158.8 million       0.00      0.00      0.00         1
#                               1995       0.00      0.00      0.00         1
#                               2010       0.00      0.00      0.00         1
#                               2015       0.00      0.00      0.00         1
#                         24 million       0.00      0.00      0.00         1
#                                  4       0.00      0.00      0.00         1
#                     663,000 copies       0.00      0.00      0.00         1
#                         April 2013       0.00      0.00      0.00         1
#                             B.I.C.       0.00      0.00      0.00         1
#                      Back to Black       0.00      0.00      0.00         1
#                               Beck       0.00      0.00      0.00         1
#                   Beyonce pregnant       0.00      0.00      0.00         1
#                    Blue Ivy Carter       0.00      0.00      0.00         2
#           Chimamanda Ngozi Adichie       0.00      0.00      0.00         1
#                           Coldplay       0.00      0.00      0.00         1
#                      Crazy in Love       0.00      0.00      0.00         1
#                Dangerously in Love       0.00      0.00      0.00         1
#                  December 13, 2013       0.00      0.00      0.00         1
#                    Destiny's Child       0.00      0.00      0.00         1
#                         Dreamgirls       0.00      0.00      0.00         1
#                    Elektra Records       0.00      0.00      0.00         1
#                            Essence       0.00      0.00      0.00         1
#                        Five months       0.00      0.00      0.00         1
#                           Flawless       0.00      0.00      0.00         1
#                             Forbes       0.00      0.00      0.00         3
#                       Freddie Gray       0.00      0.00      0.00         1
#                        Green Light       0.00      0.00      0.00         1
#                            Imagine       0.00      0.00      0.00         1
#                       January 2013       0.00      0.00      0.00         1
#                    January 7, 2012       0.00      0.00      0.00         1
#                              Jay Z       0.01      1.00      0.02         1
#                      June 28, 2011       0.00      0.00      0.00         1
#                         Kanye West       0.00      0.00      0.00         1
#                          Lady Gaga       0.00      0.00      0.00         1
#                Lenox Hill Hospital       0.00      0.00      0.00         1
#                                MTV       0.00      0.00      0.00         1
#            Madonna and Celine Dion       0.00      0.00      0.00         1
#                        Marc Nelson       0.00      0.00      0.00         1
#                       Mariah Carey       0.00      0.00      0.00         2
#      Missy Elliott and Alicia Keys       0.00      0.00      0.00         1
#                  November 18, 2008       0.00      0.00      0.00         1
#                      Phoenix House       0.00      0.00      0.00         2
#                                R&B       0.00      0.00      0.00         2
#                            Rise Up       0.00      0.00      0.00         1
#                         Rudy Perez       0.00      0.00      0.00         1
#                        Rudy Perez.       0.00      0.00      0.00         1
#                     September 2015       0.00      0.00      0.00         1
#                            Spanish       0.00      0.00      0.00         1
# St. John's United Methodist Church       0.00      0.00      0.00         1
#                           Survivor       0.00      0.00      0.00         1
#                          Telephone       0.00      0.00      0.00         1
#             The Beyoncé Experience       0.00      0.00      0.00         1
#               The Mrs. Carter Show       0.00      0.00      0.00         1
#    The Mrs. Carter Show World Tour       0.00      0.00      0.00         1
#                              Tidal       0.00      0.00      0.00         1
#                              Women       0.00      0.00      0.00         1
#                              Xerox       0.00      0.00      0.00         1
#                           a hiatus       0.00      0.00      0.00         1
#                            a rally       0.00      0.00      0.00         1
#                              beats       0.00      0.00      0.00         1
#                 boyfriend left her       0.00      0.00      0.00         1
#                       co-producing       0.00      0.00      0.00         1
#               co-producing credits       0.00      0.00      0.00         1
#    documents obtained by WikiLeaks       0.00      0.00      0.00         1
#                        exclusively       0.00      0.00      0.00         1
#                               four       0.00      0.00      0.00         1
#                        four nights       0.00      0.00      0.00         1
#          head of the G7 in Germany       0.00      0.00      0.00         1
#           her mother's maiden name       0.00      0.00      0.00         1
#                         late 1990s       0.00      0.00      0.00         1
#                      mixed reviews       0.00      0.00      0.00         1
#      more than double her earnings       0.00      0.00      0.00         1
#                        number four       0.00      0.00      0.00         1
#                 pop, soul and funk       0.00      0.00      0.00         1
#                                six       0.00      0.00      0.00         2
#       the American national anthem       0.00      0.00      0.00         1
#      the head of the G7 in Germany       0.00      0.00      0.00         1
#                   the iTunes Store       0.00      0.00      0.00         1
#                              three       0.00      0.00      0.00         2
#
#                           accuracy                           0.01        89
#                          macro avg       0.00      0.01      0.00        89
#                       weighted avg       0.00      0.01      0.00        89
# C:\Users\Bharadwaj\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Bharadwaj\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Bharadwaj\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
